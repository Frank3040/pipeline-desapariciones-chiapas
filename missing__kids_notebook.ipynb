# %%
import pandas as pd

# %%
df = pd.read_csv("base-desapariciones-dataton-2025.csv")

# %%
df.head()
# Out:
#      Sexo Edad Grupo etario                             Municipio  \
# 0   Mujer   16      12 a 17             Tuxtla Gutiérrez, Chiapas
# 1  Hombre   12      12 a 17  San Cristóbal de Las Casas, Chiapas
# 2   Mujer   12      12 a 17             Tuxtla Gutiérrez, Chiapas
# 3   Mujer   14      12 a 17  San Cristóbal de Las Casas, Chiapas
# 4   Mujer   15      12 a 17                   Tapachula, Chiapas
#
#           Región Colonia/Localidad Migrante Fecha de desaparición  \
# 0  Metropolitana   No especificado       No              2/1/2019
# 1          Altos   No especificado       No              7/1/2019
# 2  Metropolitana   No especificado       No              7/1/2019
# 3          Altos   No especificado       No              8/1/2019
# 4      Soconusco   No especificado       No              8/1/2019
#
#   Día de la semana          Horario  ... Rango desaparición Reincidencia  \
# 0           Martes  No especificada  ...          No aplica           No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2842 entries, 0 to 2841
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Sexo                           2842 non-null   object
#  1   Edad                           2842 non-null   object
#  2   Grupo etario                   2842 non-null   object
#  3   Municipio                      2842 non-null   object
#  4   Región                         2842 non-null   object
#  5   Colonia/Localidad              2842 non-null   object
#  6   Migrante                       2842 non-null   object
#  7   Fecha de desaparición          2842 non-null   object
#  8   Día de la semana               2842 non-null   object
#  9   Horario                        2842 non-null   object
#  10  Estatus                        2842 non-null   object
#  11  Fecha de localización          2842 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Sexo                                0
# Edad                                0
# Grupo etario                        0
# Municipio                           0
# Región                              0
# Colonia/Localidad                   0
# Migrante                            0
# Fecha de desaparición               0
# Día de la semana                    0
# Horario                             0
# Estatus                             0
# Fecha de localización               0
# Días sin localizar                  0
# Rango desaparición                  0
# Reincidencia                        0
# Número de reincidencia              0
# Desaparición múltiple               0
# Persona con quién desapareció       0
# Hipótesis                           0
# Fuente                             32
# Sistematizó                         8
# Unnamed: 21                      2809
# Unnamed: 22                      2842
# dtype: int64
